# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.data_access.hf_client import get_frame, frame_stream
from src.dsp.windowing import apply_window
from src.dsp.range_fft import process_range_fft

# %%
frame = get_frame(0)

# %%
frame
# Out:
# array([[[[ -97.+12.j,  -59.+19.j],
#          [  90.+18.j,   77.+28.j],
#          [-108.+65.j,  -39.+27.j],
#          [ -83.-59.j,   14. +0.j]],
#
#         [[ -79. +8.j,  -53. +8.j],
#          [  93. +3.j,   61.+17.j],
#          [-109.+73.j,  -34.+19.j],
#          [ -83.-52.j,   18. +2.j]],
#
#         [[ -88.+15.j,  -65.+22.j],
#          [  98.+23.j,   64.+23.j],
#          [-121.+77.j,  -34.+24.j],
#          [ -83.-73.j,   19. +1.j]],
#
#         ...,
#
#         [[ -90. +9.j,  -70.+24.j],
#          [  89.+16.j,   61.+33.j],
#          [-116.+87.j,  -34.+38.j],
#          [ -89.-51.j,   18.+14.j]],
#
#         [[ -92. +9.j,  -71.+28.j],
#          [  90.+15.j,   56.+34.j],
#          [-124.+85.j,  -35.+42.j],
#          [ -90.-57.j,   11.+12.j]],
#
#         [[ -96. -1.j,  -81.+32.j],
#          [  85.+14.j,   64.+29.j],
#          [-122.+83.j,  -40.+37.j],
#          [ -86.-45.j,   13. +5.j]]],
#
#
#        [[[ -64. +4.j,  -57. +5.j],
#          [  72. +7.j,   57. +7.j],
#          [-101.+52.j,  -20.+19.j],
#          [ -65.-61.j,   12. +6.j]],
#
#         [[ -79.+14.j,  -57. +3.j],
#          [  80. +8.j,   53.+13.j],
#          [ -94.+56.j,  -34.+27.j],
#          [ -60.-55.j,   13. -1.j]],
#
#         [[ -75.+10.j,  -66. +9.j],
#          [  76. +5.j,   64.+11.j],
#          [ -94.+58.j,  -31.+24.j],
#          [ -64.-60.j,    5. +0.j]],
#
#         ...,
#
#         [[ -73. -7.j,  -68.-15.j],
#          [  83. -8.j,   39. -5.j],
#          [ -99.+45.j,  -41. +9.j],
#          [ -56.-63.j,    2.-10.j]],
#
#         [[ -65.-17.j,  -66. -6.j],
#          [  76. +1.j,   47. -2.j],
#          [ -90.+38.j,  -46. +8.j],
#          [ -64.-55.j,    6.-11.j]],
#
#         [[ -68. -3.j,  -68.-21.j],
#          [  81. -4.j,   53.+11.j],
#          [ -93.+34.j,  -44. +2.j],
#          [ -61.-70.j,    2.-11.j]]],
#
#
#        [[[ -56. +9.j,  -41. +5.j],
#          [  68. +7.j,   57. +8.j],
#          [ -60.+41.j,  -26. +8.j],
#          [ -40.-38.j,    5.-17.j]],
#
#         [[ -44. -1.j,  -44. +4.j],
#          [  65.+15.j,   56. +3.j],
#          [ -71.+57.j,  -26.+10.j],
#          [ -36.-39.j,    8. +5.j]],
#
#         [[ -45. -5.j,  -42. -8.j],
#          [  67. +9.j,   45.+20.j],
#          [ -73.+46.j,  -30.+19.j],
#          [ -44.-28.j,   12. +8.j]],
#
#         ...,
#
#         [[ -41. +8.j,  -28.+10.j],
#          [  82.+21.j,   66.+12.j],
#          [ -58.+49.j,  -14.+14.j],
#          [ -34.-39.j,   25. -5.j]],
#
#         [[ -43.+19.j,  -36. -7.j],
#          [  86.+19.j,   71.+13.j],
#          [ -61.+52.j,   -9.+19.j],
#          [ -40.-34.j,   26. +8.j]],
#
#         [[ -51.+17.j,  -27. +7.j],
#          [  68.+29.j,   59.+16.j],
#          [ -59.+56.j,   -9.+22.j],
#          [ -30.-36.j,   21. +2.j]]],
#
#
#        ...,
#
#
#        [[[ -33. -2.j,  -26.+10.j],
#          [ -13. +0.j,  -21.+32.j],
#          [ -21.+10.j,  -14.+29.j],
#          [  -8. -2.j,  -11.+13.j]],
#
#         [[ -31.-11.j,  -20. +6.j],
#          [ -20. -3.j,   -6.+17.j],
#          [ -15.+11.j,  -20.+26.j],
#          [  -4. +8.j,  -10.+17.j]],
#
#         [[ -41. -7.j,  -20. +0.j],
#          [ -10. -6.j,   -7.+26.j],
#          [ -26. +9.j,  -15.+29.j],
#          [ -13. +1.j,  -12. +9.j]],
#
#         ...,
#
#         [[ -25.+15.j,    0.+16.j],
#          [  -7.+12.j,   11.+26.j],
#          [ -12.+16.j,    9.+31.j],
#          [   7.+19.j,    4. +5.j]],
#
#         [[ -28. +4.j,   -1.+11.j],
#          [  -2.+10.j,    8.+32.j],
#          [  -7.+27.j,   -1.+15.j],
#          [   3.+14.j,    1.+21.j]],
#
#         [[ -18.+11.j,    4. +7.j],
#          [   0. +9.j,    7.+35.j],
#          [  -3.+21.j,    0.+25.j],
#          [  14.+13.j,   -2.+13.j]]],
#
#
#        [[[  -8.-26.j,  -10.-13.j],
#          [  13. -8.j,   -9. -6.j],
#          [  -2.-14.j,  -21. -8.j],
#          [  14. -7.j,   -3. -9.j]],
#
#         [[  -6.-23.j,   -5.-14.j],
#          [  18.-12.j,   -8. +7.j],
#          [  -4.-17.j,  -15.-13.j],
#          [  11.-10.j,   -4. -6.j]],
#
#         [[  -2.-19.j,   -8.-29.j],
#          [  -2.-16.j,   -9.-11.j],
#          [  -2.-11.j,  -22.-10.j],
#          [   9.-13.j,   -6.-17.j]],
#
#         ...,
#
#         [[ -32.-22.j,  -33. -1.j],
#          [  -2. -6.j,  -19. +2.j],
#          [ -30. -8.j,  -31. -1.j],
#          [   0. -8.j,  -12.+10.j]],
#
#         [[ -26.-19.j,  -30. -5.j],
#          [  -6. -7.j,  -19. +8.j],
#          [ -16. -8.j,  -42. +4.j],
#          [  -8. -7.j,  -22. +9.j]],
#
#         [[ -32.-15.j,  -36. +0.j],
#          [  -8. -6.j,  -18. +7.j],
#          [ -21. -7.j,  -32. -6.j],
#          [  -7.-16.j,  -25. +0.j]]],
#
#
#        [[[ -22.+12.j,    5. -4.j],
#          [  -1.+15.j,    4. +9.j],
#          [  -1.+16.j,    0. +9.j],
#          [   7. +9.j,    1.+20.j]],
#
#         [[ -10. +4.j,    3. +4.j],
#          [   3.+23.j,   16.+14.j],
#          [   0.+20.j,    7. -4.j],
#          [  17. +9.j,   21. +8.j]],
#
#         [[  -6. +8.j,    5. +4.j],
#          [   6.+25.j,   -3.+15.j],
#          [  11.+25.j,    5. +7.j],
#          [  11.+14.j,    4.+21.j]],
#
#         ...,
#
#         [[   9. -5.j,   -4.-21.j],
#          [  13. +0.j,   18. -5.j],
#          [  11. -3.j,   -5.-15.j],
#          [  20. +2.j,    9. -1.j]],
#
#         [[   0.-13.j,   -5.-19.j],
#          [  17.+12.j,   15. +0.j],
#          [  13.+14.j,    4.-17.j],
#          [  23. +1.j,   11. -1.j]],
#
#         [[  -7.-22.j,   -6.-10.j],
#          [  17. +7.j,    8. +3.j],
#          [   6. -8.j,    4.-11.j],
#          [  31. +9.j,   12. -3.j]]]], shape=(128, 255, 4, 2))

# %%
frame_windowed= apply_window(frame)

# %%
frame_windowed
# Out:
# array([[[[-0.+0.j, -0.+0.j],
#          [ 0.+0.j,  0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.-0.j,  0.+0.j]],
#
#         [[-0.+0.j, -0.+0.j],
#          [ 0.+0.j,  0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.-0.j,  0.+0.j]],
#
#         [[-0.+0.j, -0.+0.j],
#          [ 0.+0.j,  0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.-0.j,  0.+0.j]],
#
#         ...,
#
#         [[-0.+0.j, -0.+0.j],
#          [ 0.+0.j,  0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.-0.j,  0.+0.j]],
#
#         [[-0.+0.j, -0.+0.j],
#          [ 0.+0.j,  0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.-0.j,  0.+0.j]],
#
#         [[ 0.-0.j, -0.+0.j],
#          [ 0.+0.j,  0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.-0.j,  0.+0.j]]],
#
#
#        [[[-0.+0.j, -0.+0.j],
#          [ 0.+0.j,  0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.-0.j,  0.+0.j]],
#
#         [[-0.+0.j, -0.+0.j],
#          [ 0.+0.j,  0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.-0.j,  0.+0.j]],
#
#         [[-0.+0.j, -0.+0.j],
#          [ 0.+0.j,  0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.-0.j,  0.+0.j]],
#
#         ...,
#
#         [[ 0.-0.j,  0.-0.j],
#          [ 0.+0.j,  0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.-0.j,  0.+0.j]],
#
#         [[ 0.-0.j,  0.-0.j],
#          [ 0.+0.j,  0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.-0.j,  0.+0.j]],
#
#         [[ 0.-0.j,  0.-0.j],
#          [ 0.+0.j,  0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.-0.j,  0.+0.j]]],
#
#
#        [[[-0.+0.j, -0.+0.j],
#          [ 0.+0.j,  0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.-0.j,  0.+0.j]],
#
#         [[ 0.-0.j, -0.+0.j],
#          [ 0.+0.j,  0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.-0.j,  0.+0.j]],
#
#         [[ 0.-0.j,  0.-0.j],
#          [ 0.+0.j,  0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.-0.j,  0.+0.j]],
#
#         ...,
#
#         [[-0.+0.j, -0.+0.j],
#          [ 0.+0.j,  0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.-0.j,  0.+0.j]],
#
#         [[-0.+0.j,  0.-0.j],
#          [ 0.+0.j,  0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.-0.j,  0.+0.j]],
#
#         [[-0.+0.j, -0.+0.j],
#          [ 0.+0.j,  0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.-0.j,  0.+0.j]]],
#
#
#        ...,
#
#
#        [[[ 0.-0.j, -0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.-0.j, -0.+0.j]],
#
#         [[ 0.-0.j, -0.+0.j],
#          [ 0.-0.j, -0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [-0.+0.j, -0.+0.j]],
#
#         [[ 0.-0.j, -0.+0.j],
#          [ 0.-0.j, -0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [-0.+0.j, -0.+0.j]],
#
#         ...,
#
#         [[-0.+0.j,  0.+0.j],
#          [-0.+0.j,  0.+0.j],
#          [-0.+0.j,  0.+0.j],
#          [ 0.+0.j,  0.+0.j]],
#
#         [[-0.+0.j, -0.+0.j],
#          [-0.+0.j,  0.+0.j],
#          [-0.+0.j, -0.+0.j],
#          [ 0.+0.j,  0.+0.j]],
#
#         [[-0.+0.j,  0.+0.j],
#          [ 0.+0.j,  0.+0.j],
#          [-0.+0.j,  0.+0.j],
#          [ 0.+0.j, -0.+0.j]]],
#
#
#        [[[ 0.-0.j,  0.-0.j],
#          [ 0.+0.j,  0.-0.j],
#          [ 0.-0.j,  0.-0.j],
#          [ 0.+0.j,  0.-0.j]],
#
#         [[ 0.-0.j,  0.-0.j],
#          [ 0.+0.j, -0.+0.j],
#          [ 0.-0.j,  0.-0.j],
#          [ 0.+0.j,  0.-0.j]],
#
#         [[ 0.-0.j,  0.-0.j],
#          [ 0.-0.j,  0.-0.j],
#          [ 0.-0.j,  0.-0.j],
#          [ 0.+0.j,  0.-0.j]],
#
#         ...,
#
#         [[ 0.-0.j,  0.-0.j],
#          [ 0.-0.j, -0.+0.j],
#          [ 0.-0.j,  0.-0.j],
#          [ 0.+0.j, -0.+0.j]],
#
#         [[ 0.-0.j,  0.-0.j],
#          [ 0.-0.j, -0.+0.j],
#          [ 0.-0.j, -0.+0.j],
#          [ 0.-0.j, -0.+0.j]],
#
#         [[ 0.-0.j, -0.+0.j],
#          [ 0.-0.j, -0.+0.j],
#          [ 0.-0.j,  0.-0.j],
#          [ 0.-0.j, -0.+0.j]]],
#
#
#        [[[-0.+0.j,  0.+0.j],
#          [-0.+0.j,  0.+0.j],
#          [-0.+0.j,  0.+0.j],
#          [ 0.+0.j,  0.+0.j]],
#
#         [[-0.+0.j,  0.+0.j],
#          [ 0.+0.j,  0.+0.j],
#          [ 0.+0.j,  0.+0.j],
#          [ 0.+0.j,  0.+0.j]],
#
#         [[-0.+0.j,  0.+0.j],
#          [ 0.+0.j, -0.+0.j],
#          [ 0.+0.j,  0.+0.j],
#          [ 0.+0.j,  0.+0.j]],
#
#         ...,
#
#         [[ 0.+0.j,  0.-0.j],
#          [ 0.+0.j,  0.+0.j],
#          [ 0.+0.j,  0.-0.j],
#          [ 0.+0.j,  0.+0.j]],
#
#         [[ 0.+0.j,  0.-0.j],
#          [ 0.+0.j,  0.+0.j],
#          [ 0.+0.j,  0.+0.j],
#          [ 0.+0.j,  0.+0.j]],
#
#         [[ 0.-0.j,  0.-0.j],
#          [ 0.+0.j,  0.+0.j],
#          [ 0.+0.j,  0.+0.j],
#          [ 0.+0.j,  0.+0.j]]]], shape=(128, 255, 4, 2))

# %%
range = process_range_fft(frame_windowed)

# %%
range
# Out:
# (array([[[[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          ...,
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]]],
#
#
#         [[[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          ...,
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]]],
#
#
#         [[[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          ...,
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]]],
#
#
#         ...,
#
#
#         [[[ 0.+0.j, -0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j, -0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j, -0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          ...,
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]]],
#
#
#         [[[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          ...,
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]]],
#
#
#         [[[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          ...,
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]],
#
#          [[ 0.+0.j,  0.+0.j],
#           [ 0.+0.j,  0.+0.j]]]], shape=(128, 255, 2, 2)),
#  array([0., 1.]))

# %% [markdown]
# well that is not promising. all the values turned out zeros

# %% [markdown]
# there must be something wrong with the pipeline
